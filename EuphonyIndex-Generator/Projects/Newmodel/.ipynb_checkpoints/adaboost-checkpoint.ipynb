# %% [markdown]
# # Adaboost(ロジスティック回帰)

# %%
library(ggplot2)

# %%
df <- read.csv("Newmodel-data.csv",header=T)
dat <- df[, c(11,3,4,5,6,7,8,9,10)]
odd.number <- 2*(1:113)
odd.data <- dat[odd.number,]
even.data <- dat[-odd.number,]
dat.data <- rbind(odd.data, even.data)
even.data
# Out:
#     natorcong alpha     beta      gamma     delta     epsilon zeta eta
# 1   0         14.400000 0.4333333 0.4333333 0.6111111 1       0    0
# 3   0         12.200000 0.4333333 0.4188889 0.6666667 1       0    0
# 5   0         14.533333 0.8000000 0.8000000 0.6559633 2       0    0
# 7   0         22.233333 0.6000000 0.6000000 0.6596702 1       0    0
# 9   0         21.333333 0.4000000 0.4000000 0.6593750 1       0    0
# 11  0         22.066667 0.6000000 0.6000000 0.6631420 1       0    0
# 13  0         18.233333 0.1333333 0.1333333 0.6398537 1       0    0
# 15  0          2.466667 0.0000000 0.0000000 0.4459459 1       0    0
# 17  0         10.900000 0.2000000 0.2000000 0.6330275 1       0    0
# 19  0          6.033333 0.0000000 0.0000000 0.5193370 2       0    0
# 21  0         10.866667 0.4666667 0.4666667 0.6717791 1       0    0
# 23  0          5.033333 0.2000000 0.1933333 0.6556291 2       0    0
# 25  0         20.566667 0.4333333 0.4333333 0.6434360 1       0    0
# 27  0          6.566667 0.4000000 0.4000000 0.5482234 1       0    0
# 29  0          7.700000 0.4333333 0.4333333 0.6580087 1       0    0
# 31  0         15.000000 0.3666667 0.3666667 0.6688889 1       0    0
# 33  0         18.533333 0.3000000 0.3000000 0.6834532 1       0    0
# 35  0         18.533333 0.2333333 0.2255556 0.6564748 1       0    0
# 37  0          2.000000 0.0000000 0.0000000 0.5000000 1       0    1
# 39  0         11.900000 0.6000000 0.6000000 0.6834734 1       0    0
# 41  0         43.000000 0.3333333 0.3333333 0.6550388 1       0    0
# 43  0         19.333333 0.4000000 0.4000000 0.6362069 1       0    0
# 45  0         14.533333 0.6000000 0.6000000 0.6743119 1       0    0
# 47  0          5.266667 0.0667000 0.0622000 0.6075949 1       0    0
# 49  0         16.666667 0.3333333 0.3333333 0.6280000 1       0    0
# 51  0          9.800000 0.7333333 0.7333333 0.6972789 3       0    0
# 53  0         13.500000 0.4000000 0.3866667 0.6617284 1       0    0
# 55  0          8.866667 0.2666667 0.2666667 0.6541353 1       0    0
# 57  0         21.433333 0.2666667 0.2666667 0.6469673 1       0    0
# 59  0          7.600000 0.5000000 0.5000000 0.6754386 1       0    0
# ⋮   ⋮         ⋮         ⋮         ⋮         ⋮         ⋮       ⋮    ⋮
# 167 0         26.900000 0.5000000 0.5000000 0.6765799 1       0    0
# 169 0          4.866667 0.0667000 0.0667000 0.4589041 0       0    0
# 171 0         16.100000 0.3000000 0.3000000 0.6397516 1       0    0
# 173 0          8.000000 0.5333333 0.5155556 0.6375000 1       0    0
# 175 0          7.866667 0.5333333 0.5333333 0.6398305 1       0    0
# 177 0         42.966667 0.3666667 0.3544444 0.6966641 1       0    0
# 179 0          3.933333 0.4666667 0.4666667 0.6271186 1       0    0
# 181 0         38.566667 0.4000000 0.4000000 0.6672429 1       0    0
# 183 0         14.300000 0.5333333 0.5155556 0.6783217 1       0    0
# 185 0         10.600000 0.4666667 0.4355556 0.6666667 1       0    0
# 187 0         29.433333 0.4000000 0.4000000 0.6285391 1       0    0
# 189 0          5.933333 0.0000000 0.0000000 0.5168539 2       0    0
# 191 0         21.933333 0.3333333 0.3333333 0.6200608 1       0    0
# 193 0         20.033333 0.3000000 0.3000000 0.6339434 1       0    0
# 195 0          2.800000 0.0000000 0.0000000 0.0000000 0       0    0
# 197 0         12.933333 0.5333333 0.5333333 0.6855670 1       0    0
# 199 0         20.400000 0.5666667 0.5666667 0.6830065 1       0    0
# 201 1          3.717949 0.0855000 0.0323000 0.5908046 2       0    0
# 203 1          4.982456 0.0526000 0.0290000 0.5492958 1       0    0
# 205 1          4.396226 0.0943000 0.0398000 0.4463519 1       0    0
# 207 1          4.709091 0.0545000 0.0443000 0.5289575 1       0    0
# 209 1          4.982456 0.0351000 0.0169000 0.5598592 1       0    0
# 211 1          3.483333 0.2333333 0.0339000 0.5933014 1       0    0
# 213 1          4.015038 0.0301000 0.0096900 0.5636704 1       0    0
# 215 1          4.788991 0.0734000 0.0469000 0.4923372 1       0    0
# 217 1         10.268293 0.0976000 0.0345000 0.4988124 1       0    0
# 219 1          2.729927 0.1824818 0.0403000 0.5561497 1       0    0
# 221 1          3.821918 0.0822000 0.0364000 0.5878136 1       0    0
# 223 1          4.056604 0.1132075 0.0488000 0.5418605 1       0    0
# 225 1         10.210526 0.1578947 0.0143000 0.5721649 1       0    0
#     theta
# 1   0.5714286
# 3   0.4452555
# 5   0.4746835
# 7   0.4829787
# 9   0.4823009
# 11  0.4754797
# 13  0.5184211
# 15  0.6507937
# 17  0.5063291
# 19  0.7016129
# 21  0.4297189
# 23  0.4031008
# 25  0.5152225
# 27  0.6449275
# 29  0.4340659
# 31  0.4501511
# 33  0.4292683
# 35  0.4835443
# 37  0.5000000
# 39  0.4124088
# 41  0.5085714
# 43  0.5288221
# 45  0.4382716
# 47  0.4920635
# 49  0.5406977
# 51  0.3787234
# 53  0.4597315
# 55  0.4509804
# 57  0.5089686
# 59  0.4021739
# ⋮   ⋮
# 167 0.4531250
# 169 0.8144330
# 171 0.5132743
# 173 0.4754098
# 175 0.4696133
# 177 0.4213362
# 179 0.4230769
# 181 0.4800499
# 183 0.4299065
# 185 0.4380165
# 187 0.5606838
# 189 0.7049180
# 191 0.5707763
# 193 0.5352798
# 195 2.8000000
# 197 0.4121622
# 199 0.4330357
# 201 0.4759358
# 203 0.6009390
# 205 0.8216561
# 207 0.6354167
# 209 0.5787037
# 211 0.4619565
# 213 0.5368664
# 215 0.7240437
# 217 0.8406375
# 219 0.4811594
# 221 0.4852321
# 223 0.5811209
# 225 0.6384615

# %%
adaboosting <- function(object, data, iter){ #一列目に応答数
    true_data <- data[,1]
    D_1 <- c()
    for (i in 1:nrow(data)){
        D_1 <- append(D_1, 1/nrow(data))
    }
    D_m <- matrix( , , nrow(data))
    D_m <- rbind(D_m, D_1)
    h_m <- list()
    Alpha_m <- c()
    ret <- list()
    for (i in 1:iter){
        dat0 <- data[,-1]
        dat <- cbind(object=data[,1], dat0*D_m[i+1,])
        h_m <- append(h_m, list(glm(dat$object~., data=dat, family=gaussian())))
        pred <- predict(h_m[[i]], data)
        pred[pred>=0.5] <- 1
        pred[pred<0.5] <- 0 
        E_m <- c()
        d_m <- c()
        for (j in 1:nrow(data)){
            if (pred[j] == true_data[j]){
                E_m <- append(E_m, 0)
                d_m <- append(d_m, D_m[i+1,j])
            } else {
                E_m <- append(E_m, D_m[i+1,j])
                d_m <- append(d_m, D_m[i+1,j])
            }
        }
        E_m <- sum(E_m)/sum(d_m)
        Alpha_m <- append(Alpha_m, log((1-E_m)/E_m))
        Alpha_m[is.infinite(Alpha_m)] <- 0
        d_m <- c()
        for (j in 1:nrow(data)){
            if (pred[j] == true_data[j]){
                d_m <- append(d_m, D_m[i+1,j])
            } else {
                d_m <- append(d_m, D_m[i+1,j]*exp(Alpha_m[i]))
            }
        }
        D_m <- rbind(D_m, d_m)
        ret <- append(ret, c(h_m[i], Alpha_m[i]))
    }
    return (ret) 
}

# %%
even.data$natorcong <- as.numeric(as.character(even.data$natorcong))
odd.data$natorcong <- as.numeric(as.character(odd.data$natorcong))
even.data2 <- even.data[,-c(7,8)]
odd.data2 <- odd.data[,-c(7,8)]
o.ada <- adaboosting(natorcong, odd.data2, 10)
o.ada
# Out:
# [[1]]
#
# Call:  glm(formula = dat$object ~ ., family = gaussian(), data = dat)
#
# Coefficients:
# (Intercept)        alpha         beta        gamma        delta      epsilon
#      0.6753      -0.4338     494.1373    -582.4986     -50.1760      16.2847
#       theta
#    -28.8491
#
# Degrees of Freedom: 112 Total (i.e. Null);  106 Residual
# Null Deviance:	    11.5
# Residual Deviance: 4.909 	AIC: -17.72
#
# [[2]]
# [1] 2.227078
#
# [[3]]
#
# Call:  glm(formula = dat$object ~ ., family = gaussian(), data = dat)
#
# Coefficients:
# (Intercept)        alpha         beta        gamma        delta      epsilon
#      0.0204      -0.1310      75.4206    -103.6535      11.5780       4.8124
#       theta
#      0.4550
#
# Degrees of Freedom: 112 Total (i.e. Null);  106 Residual
# Null Deviance:	    11.5
# Residual Deviance: 1.527 	AIC: -149.7
#
# [[4]]
# [1] 1.410987
#
# [[5]]
#
# Call:  glm(formula = dat$object ~ ., family = gaussian(), data = dat)
#
# Coefficients:
# (Intercept)        alpha         beta        gamma        delta      epsilon
#      0.1103      -0.1113     106.2056    -147.9256       6.4699       6.4511
#       theta
#     -1.4949
#
# Degrees of Freedom: 112 Total (i.e. Null);  106 Residual
# Null Deviance:	    11.5
# Residual Deviance: 1.937 	AIC: -122.8
#
# [[6]]
# [1] 2.065455
#
# [[7]]
#
# Call:  glm(formula = dat$object ~ ., family = gaussian(), data = dat)
#
# Coefficients:
# (Intercept)        alpha         beta        gamma        delta      epsilon
#      0.1244       0.1692     162.0689    -192.0144       0.8107       3.6971
#       theta
#     -3.0872
#
# Degrees of Freedom: 112 Total (i.e. Null);  106 Residual
# Null Deviance:	    11.5
# Residual Deviance: 4.331 	AIC: -31.88
#
# [[8]]
# [1] 1.212469
#
# [[9]]
#
# Call:  glm(formula = dat$object ~ ., family = gaussian(), data = dat)
#
# Coefficients:
# (Intercept)        alpha         beta        gamma        delta      epsilon
#      0.1587       0.1964     159.3752    -184.1029      -1.6168       3.1359
#       theta
#     -3.2553
#
# Degrees of Freedom: 112 Total (i.e. Null);  106 Residual
# Null Deviance:	    11.5
# Residual Deviance: 5.451 	AIC: -5.893
#
# [[10]]
# [1] 4.160618
#
# [[11]]
#
# Call:  glm(formula = dat$object ~ ., family = gaussian(), data = dat)
#
# Coefficients:
# (Intercept)        alpha         beta        gamma        delta      epsilon
#      0.1710       0.1542     150.1348    -175.6638      -0.6994       3.2539
#       theta
#     -3.5919
#
# Degrees of Freedom: 112 Total (i.e. Null);  106 Residual
# Null Deviance:	    11.5
# Residual Deviance: 5.457 	AIC: -5.765
#
# [[12]]
# [1] 2.72481
#
# [[13]]
#
# Call:  glm(formula = dat$object ~ ., family = gaussian(), data = dat)
#
# Coefficients:
# (Intercept)        alpha         beta        gamma        delta      epsilon
#      0.1885       0.1564     141.7423    -165.0203      -1.1826       2.8678
#       theta
#     -3.4027
#
# Degrees of Freedom: 112 Total (i.e. Null);  106 Residual
# Null Deviance:	    11.5
# Residual Deviance: 5.898 	AIC: 3.012
#
# [[14]]
# [1] 0
#
# [[15]]
#
# Call:  glm(formula = dat$object ~ ., family = gaussian(), data = dat)
#
# Coefficients:
# (Intercept)        alpha         beta        gamma        delta      epsilon
#      0.1885       0.1564     141.7423    -165.0203      -1.1826       2.8678
#       theta
#     -3.4027
#
# Degrees of Freedom: 112 Total (i.e. Null);  106 Residual
# Null Deviance:	    11.5
# Residual Deviance: 5.898 	AIC: 3.012
#
# [[16]]
# [1] 0
#
# [[17]]
#
# Call:  glm(formula = dat$object ~ ., family = gaussian(), data = dat)
#
# Coefficients:
# (Intercept)        alpha         beta        gamma        delta      epsilon
#      0.1885       0.1564     141.7423    -165.0203      -1.1826       2.8678
#       theta
#     -3.4027
#
# Degrees of Freedom: 112 Total (i.e. Null);  106 Residual
# Null Deviance:	    11.5
# Residual Deviance: 5.898 	AIC: 3.012
#
# [[18]]
# [1] 0
#
# [[19]]
#
# Call:  glm(formula = dat$object ~ ., family = gaussian(), data = dat)
#
# Coefficients:
# (Intercept)        alpha         beta        gamma        delta      epsilon
#      0.1885       0.1564     141.7423    -165.0203      -1.1826       2.8678
#       theta
#     -3.4027
#
# Degrees of Freedom: 112 Total (i.e. Null);  106 Residual
# Null Deviance:	    11.5
# Residual Deviance: 5.898 	AIC: 3.012
#
# [[20]]
# [1] 0

# %%
obj <- matrix(, , nrow(even.data2))
for (i in 2*(1:(length(o.ada)/2))){
    obj <- rbind(obj, o.ada[[i]]*predict(o.ada[[i-1]], even.data2))
}
logistic.ada <- 1/(1+exp(-colSums(obj[-1,])))
logistic.ada2 <- 1/(1+exp(-colSums(obj[-1,])))
logistic.ada2[logistic.ada2>=0.5] <- 1
logistic.ada2[logistic.ada2<0.5] <- 0
correct <- 100*sum(logistic.ada2==even.data2$natorcong)/nrow(even.data2)
names(correct) <- "正解率"
correct
# Out:
#   正解率
# 97.34513

# %%
logistic <- 1/(1+exp(predict(o.ada[[1]], even.data2)))

# %%
index <- transform(transform(logistic.ada, 残差=even.data2[,1]-logistic.ada), Species="adaboost")
               #transform(transform(logistic, 残差=even.data2[,1]-logistic), Species="logistic"))

# %%
ggplot(index,aes(x=Species,y=残差))+geom_boxplot()+labs(title="箱ひげ図")
# Out:
# plot without title

# %%
ggplot(index, aes(x = 残差))+geom_density(aes(fill=Species),size=0.5,alpha=0.5)+labs(title="確率密度関数")
# Out:
# plot without title
